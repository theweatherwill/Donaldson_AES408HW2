# %%
import geopandas as gpd
import pandas as pd

# %%
towns = gpd.read_file("C:/Users/thewe/OneDrive/Desktop/College/AES408/homework/HW2/Donaldson_AES408HW2/cb_2024_01_place_500k")

# %%
towns
# Out:
#     STATEFP PLACEFP   PLACENS           GEOIDFQ    GEOID         NAME  \
# 0        01   32704  02403782  1600000US0132704  0132704   Haleyville
# 1        01   45472  02406131  1600000US0145472  0145472     McIntosh
# 2        01   53784  02406982  1600000US0153784  0153784      Newbern
# 3        01   78204  02405634  1600000US0178204  0178204       Valley
# 4        01   02836  02405172  1600000US0102836  0102836      Ashford
# ..      ...     ...       ...               ...      ...          ...
# 589      01   63984  02407191  1600000US0163984  0163984   Reece City
# 590      01   29296  02406555  1600000US0129296  0129296  Gaylesville
# 591      01   44536  02406051  1600000US0144536  0144536  Lowndesboro
# 592      01   55440  02407012  1600000US0155440  0155440    Notasulga
# 593      01   63495  02582695  1600000US0163495  0163495          Ray
#
#              NAMELSAD STUSPS STATE_NAME LSAD     ALAND  AWATER  \
# ...

# %%
towns_reix = towns.set_index("NAME")

# %%
towns_reix
# Out:
#             STATEFP PLACEFP   PLACENS           GEOIDFQ    GEOID  \
# NAME
# Haleyville       01   32704  02403782  1600000US0132704  0132704
# McIntosh         01   45472  02406131  1600000US0145472  0145472
# Newbern          01   53784  02406982  1600000US0153784  0153784
# Valley           01   78204  02405634  1600000US0178204  0178204
# Ashford          01   02836  02405172  1600000US0102836  0102836
# ...             ...     ...       ...               ...      ...
# Reece City       01   63984  02407191  1600000US0163984  0163984
# Gaylesville      01   29296  02406555  1600000US0129296  0129296
# Lowndesboro      01   44536  02406051  1600000US0144536  0144536
# Notasulga        01   55440  02407012  1600000US0155440  0155440
# Ray              01   63495  02582695  1600000US0163495  0163495
#
#                      NAMELSAD STUSPS STATE_NAME LSAD     ALAND  AWATER  \
# NAME
# Haleyville    Haleyville city     AL    Alabama   25  21713018  130983
# ...

# %%
towns_reix_utm = towns_reix.to_crs(epsg=26916)

# %%
towns_reix_utm.crs
# Out:
# <Projected CRS: EPSG:26916>
# Name: NAD83 / UTM zone 16N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: North America - between 90°W and 84°W - onshore and offshore. Canada - Manitoba; Nunavut; Ontario. United States (USA) - Alabama; Arkansas; Florida; Georgia; Indiana; Illinois; Kentucky; Louisiana; Michigan; Minnesota; Mississippi; Missouri; North Carolina; Ohio; Tennessee; Wisconsin.
# - bounds: (-90.0, 23.97, -84.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 16N
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
town_circles = towns_reix_utm.minimum_bounding_circle()

# %%
towns_reix_utm.geometry.area
# Out:
# NAME
# Haleyville     2.182938e+07
# McIntosh       2.576485e+06
# Newbern        3.011000e+06
# Valley         3.357408e+07
# Ashford        1.610881e+07
#                    ...
# Reece City     9.262809e+06
# Gaylesville    3.717771e+06
# Lowndesboro    2.046922e+06
# Notasulga      3.660692e+07
# Ray            2.465204e+07
# Length: 594, dtype: float64

# %%
town_circles.area
# Out:
# NAME
# Haleyville     1.336607e+08
# McIntosh       5.249772e+06
# Newbern        4.957738e+06
# Valley         1.940474e+08
# Ashford        2.539416e+07
#                    ...
# Reece City     7.913342e+07
# Gaylesville    1.184372e+07
# Lowndesboro    5.114317e+06
# Notasulga      6.064219e+07
# Ray            4.478678e+07
# Length: 594, dtype: float64

# %%
difference = town_circles.area - towns_reix_utm.geometry.area

# %%
difference
# Out:
# NAME
# Haleyville     1.118313e+08
# McIntosh       2.673287e+06
# Newbern        1.946737e+06
# Valley         1.604733e+08
# Ashford        9.285357e+06
#                    ...
# Reece City     6.987061e+07
# Gaylesville    8.125948e+06
# Lowndesboro    3.067395e+06
# Notasulga      2.403527e+07
# Ray            2.013474e+07
# Length: 594, dtype: float64

# %%
# The closer to zero they are, the more round the border is
difference.sort_values(ascending=True)
# Out:
# NAME
# Goldville         9.943529e+04
# Coffee Springs    1.147855e+05
# Brantley          1.726092e+05
# Oakman            2.250186e+05
# McMullen          3.028714e+05
#                       ...
# Mobile            7.536702e+08
# Hoover            8.752349e+08
# Tuscaloosa        1.397459e+09
# Huntsville        1.502433e+09
# Birmingham        1.670255e+09
# Length: 594, dtype: float64
